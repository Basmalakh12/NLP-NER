# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ner_datasetreference.csv', encoding='ISO-8859-1')
df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
df.POS.value_counts()
# Out:
# NN      145807
# NNP     131426
# IN      120996
# DT       98454
# JJ       78412
# NNS      75840
# .        47831
# VBD      39379
# ,        32757
# VBN      32328
# VBZ      24960
# CD       24695
# VB       24211
# CC       23716
# TO       23061
# RB       20252
# VBG      19125
# VBP      16158
# PRP      13318
# POS      11257
# PRP$      8655
# MD        6973
# ``        3728
# WDT       3698
# JJS       3034
# JJR       2967
# WP        2542
# NNPS      2521
# RP        2490
# WRB       2184
# $         1149
# RBR       1055
# :          795
# RRB        679
# LRB        678
# EX         663
# RBS        296
# ;          214
# PDT        147
# WP$         99
# UH          24
# FW           1
# Name: POS, dtype: int64

# %%
df['IN'] = df['POS'].apply(lambda x: 1 if x =='IN' else 0)

# %%
df.shape
# Out:
# (1048575, 5)

# %%
df.head()
# Out:
#     Sentence #           Word  POS Tag  IN
# 0  Sentence: 1      Thousands  NNS   O   0
# 1          NaN             of   IN   O   1
# 2          NaN  demonstrators  NNS   O   0
# 3          NaN           have  VBP   O   0
# 4          NaN        marched  VBN   O   0

# %%
#Train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Word, df.IN, test_size=0.2)

# %%
X_train.shape
# Out:
# (838860,)

# %%
X_test.shape
# Out:
# (209715,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 465643     recovery
# 294436       people
# 874834    customers
# 162081          the
# Name: Word, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 465643    0
# 294436    0
# 874834    0
# 162081    0
# Name: IN, dtype: int64

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %%
# Create bag of words representation using CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <838860x25630 sparse matrix of type '<class 'numpy.int64'>'
# 	with 744759 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train_cv.shape
# Out:
# (838860, 25630)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'andorra'

# %%
v.vocabulary_
# Out:
# {'recovery': 18905,
#  'people': 17140,
#  'customers': 6069,
#  'the': 23093,
#  'victory': 24553,
#  'is': 12094,
#  'pilots': 17381,
#  'taliban': 22755,
#  'to': 23305,
#  'in': 11497,
#  'storm': 22096,
#  'touchdowns': 23430,
#  'for': 9207,
#  'looked': 13821,
#  'bilateral': 3289,
#  'scandal': 20327,
#  'developing': 6756,
#  'soldiers': 21510,
#  'thursday': 23207,
#  'wikileaks': 25089,
#  'and': 1759,
#  'crimes': 5914,
#  'donors': 7284,
#  '10': 22,
#  'news': 15858,
#  'california': 4051,
#  'are': 2080,
#  'main': 14083,
#  'that': 23087,
#  'effect': 7699,
#  'from': 9434,
#  'year': 25376,
#  'monday': 15151,
#  'iraqi': 12064,
#  'prime': 17953,
#  'before': 3037,
#  'rwandans': 19984,
#  'politicized': 17606,
#  'new': 15845,
#  'received': 18834,
#  'while': 25039,
#  'supplies': 22456,
#  'racing': 18493,
#  'truck': 23696,
#  'rok': 19779,
#  'stable': 21869,
#  'tunes': 23758,
#  'at': 2341,
#  'some': 21552,
#  'tune': 23757,
#  'bomb': 3536,
#  'of': 16282,
#  'was': 24873,
#  'third': 23151,
#  'witnesses': 25180,
#  'peace': 17061,
#  'yemen': 25387,
#  'underscore': 24004,
#  'obama': 16182,
#  'incentives': 11525,
#  'after': 1295,
#  'during': 7532,
#  'his': 10941,
#  'billion': 3303,
#  'agreements': 1343,
#  'statement': 21954,
#  'on': 16376,
#  'warning': 24851,
#  'push': 18318,
#  '617': 677,
#  'day': 6244,
#  'country': 5796,
#  'party': 16949,
#  'bike': 3286,
#  'if': 11335,
#  'civil': 4839,
#  'produce': 18033,
#  'crude': 5976,
#  'four': 9313,
#  'have': 10653,
#  'spokesman': 21783,
#  'days': 6250,
#  'lower': 13870,
#  'including': 11542,
#  'chavez': 4599,
#  'who': 25057,
#  'hamas': 10441,
#  'president': 17886,
#  'known': 12985,
#  'korea': 13037,
#  'warned': 24849,
#  'wedding': 24956,
#  'been': 3033,
#  'activists': 1078,
#  'income': 11545,
#  'won': 25199,
#  'cartoons': 4261,
#  'destruction': 6701,
#  'an': 1731,
#  'fraud': 9368,
#  'fujimori': 9465,
#  'svinarov': 22570,
#  'students': 22219,
#  'were': 24996,
#  '17': 163,
#  'missile': 15013,
#  'van': 24401,
#  'two': 23828,
#  'attack': 2388,
#  'despite': 6682,
#  'scourge': 20424,
#  'help': 10781,
#  'vote': 24705,
#  'border': 3585,
#  'highest': 10875,
#  'guangdong': 10184,
#  'would': 25258,
#  'quit': 18457,
#  'reports': 19279,
#  'lawsuit': 13376,
#  'cleanup': 4896,
#  'de': 6256,
#  'also': 1612,
#  'percent': 17152,
#  'floods': 9111,
#  'private': 17984,
#  'united': 24110,
#  'now': 16109,
#  'economic': 7635,
#  'independence': 11583,
#  'military': 14873,
#  'female': 8837,
#  'sites': 21239,
#  'much': 15352,
#  'ignore': 11349,
#  'david': 6230,
#  'bankruptcy': 2799,
#  'condemned': 5348,
#  'end': 7941,
#  'him': 10912,
#  'traveling': 23593,
#  'still': 22041,
#  'styled': 22242,
#  'failing': 8612,
#  'taking': 22738,
#  'province': 18199,
#  'hurricanes': 11227,
#  'afghanistan': 1279,
#  'will': 25101,
#  'currently': 6054,
#  'say': 20313,
#  'website': 24952,
#  'today': 23312,
#  'its': 12154,
#  'under': 23970,
#  'pirates': 17407,
#  'not': 16062,
#  'northeast': 16046,
#  'election': 7761,
#  'critics': 5939,
#  'freivalds': 9394,
#  'free': 9377,
#  'enjoy': 8001,
#  'intercepted': 11911,
#  'assailants': 2267,
#  'basque': 2918,
#  'sport': 21796,
#  'socialist': 21468,
#  'killed': 12901,
#  'last': 13313,
#  'into': 11987,
#  'india': 11590,
#  'remote': 19183,
#  'following': 9182,
#  'korean': 13038,
#  'has': 10612,
#  'over': 16643,
#  'top': 23378,
#  '1990': 364,
#  'agency': 1313,
#  'kurds': 13131,
#  'several': 20725,
#  'said': 20084,
#  'other': 16557,
#  'house': 11137,
#  'with': 25162,
#  'emerged': 7852,
#  'presidential': 17887,
#  'laborer': 13180,
#  'site': 21238,
#  'closer': 4950,
#  'region': 19035,
#  'affairs': 1255,
#  'inflows': 11695,
#  'took': 23373,
#  'up': 24229,
#  'living': 13730,
#  'morales': 15209,
#  'way': 24912,
#  'confirmed': 5399,
#  'virus': 24630,
#  'alonso': 1604,
#  'consitutional': 5490,
#  'welch': 24976,
#  'claimed': 4849,
#  'justice': 12545,
#  'bob': 3483,
#  'gulf': 10265,
#  'gazprom': 9667,
#  'badly': 2644,
#  'neighbors': 15787,
#  'subsidized': 22279,
#  'unity': 24114,
#  'this': 23157,
#  'electoral': 7763,
#  'official': 16302,
#  'bangalore': 2781,
#  'they': 23130,
#  'leader': 13402,
#  'discovery': 6985,
#  'senate': 20607,
#  'operation': 16416,
#  'charges': 4566,
#  'should': 21018,
#  'era': 8118,
#  'roadside': 19704,
#  'review': 19533,
#  'frozen': 9444,
#  '57': 650,
#  'iraq': 12063,
#  'states': 21956,
#  'colonel': 5083,
#  'stop': 22080,
#  'about': 922,
#  'foreign': 9231,
#  'russian': 19964,
#  'underground': 23990,
#  'death': 6278,
#  'staff': 21874,
#  'move': 15317,
#  'which': 25038,
#  'analysts': 1736,
#  'negotiations': 15777,
#  'computing': 5300,
#  '2003': 383,
#  'attacks': 2393,
#  'tadic': 22691,
#  'he': 10681,
#  'china': 4697,
#  'elements': 7778,
#  'representative': 19284,
#  'rocket': 19746,
#  'propelled': 18116,
#  'take': 22729,
#  'joined': 12429,
#  'succeeded': 22304,
#  'wednesday': 24958,
#  'head': 10682,
#  'detained': 6710,
#  'hands': 10495,
#  'solve': 21537,
#  'prevent': 17923,
#  'producer': 18035,
#  'graves': 10060,
#  'adjacent': 1144,
#  'week': 24960,
#  '32': 504,
#  'old': 16342,
#  'may': 14499,
#  'world': 25238,
#  'continued': 5587,
#  'out': 16584,
#  'voting': 24711,
#  'campaigning': 4091,
#  'boosting': 3577,
#  'those': 23164,
#  'saturday': 20286,
#  'month': 15187,
#  'almost': 1597,
#  'criminal': 5915,
#  'll': 13739,
#  'airport': 1418,
#  'falkland': 8634,
#  '92': 798,
#  '000': 1,
#  'terror': 23034,
#  'commented': 5158,
#  'one': 16382,
#  'treaties': 23607,
#  'talks': 22761,
#  'hours': 11136,
#  'student': 22218,
#  'insurgency': 11864,
#  'pact': 16769,
#  'workers': 25227,
#  'than': 23075,
#  'pushed': 18319,
#  'forces': 9220,
#  'power': 17756,
#  'cinderella': 4796,
#  'government': 9994,
#  'sizable': 21253,
#  'hall': 10419,
#  'stormed': 22097,
#  'agreed': 1340,
#  '28': 479,
#  'club': 4966,
#  'spying': 21832,
#  'all': 1548,
#  'spain': 21656,
#  'thousands': 23171,
#  'events': 8285,
#  'secessionist': 20495,
#  'mr': 15337,
#  'disarm': 6938,
#  'pace': 16754,
#  'army': 2138,
#  'she': 20873,
#  'foreigners': 9233,
#  'adulyadej': 1199,
#  'authorities': 2476,
#  'draw': 7386,
#  'three': 23178,
#  'double': 7305,
#  'due': 7480,
#  'bushehr': 3956,
#  'gagra': 9538,
#  'stands': 21921,
#  'film': 8931,
#  'ally': 1590,
#  'impose': 11466,
#  'al': 1457,
#  'qaida': 18348,
#  'palestinians': 16818,
#  'as': 2200,
#  'birds': 3330,
#  'cheikh': 4630,
#  'when': 25030,
#  'cairo': 4034,
#  'became': 3012,
#  'five': 9037,
#  'financial': 8952,
#  'palestinian': 16817,
#  'immediately': 11401,
#  'sharon': 20852,
#  'motorcycles': 15282,
#  'traditionally': 23500,
#  '200': 378,
#  'profited': 18061,
#  'gm': 9904,
#  'iran': 12059,
#  'nuclear': 16124,
#  'counting': 5793,
#  'independently': 11585,
#  'says': 20318,
#  'sold': 21508,
#  'kurdish': 13129,
#  'indian': 11591,
#  'first': 9015,
#  'season': 20480,
#  'bold': 3514,
#  'but': 3972,
#  'weaken': 24927,
#  'fiorina': 8983,
#  'soldier': 21509,
#  'western': 25002,
#  'town': 23463,
#  'combat': 5112,
#  'mobile': 15069,
#  'alpha': 1607,
#  'nato': 15685,
#  'presidency': 17885,
#  'annexation': 1841,
#  'production': 18040,
#  'counterpart': 5787,
#  'warnings': 24852,
#  'eight': 7728,
#  'chinese': 4700,
#  'exploded': 8467,
#  'court': 5813,
#  'mentioned': 14699,
#  'health': 10703,
#  'urging': 24279,
#  'made': 14013,
#  'remain': 19154,
#  'high': 10873,
#  'then': 23107,
#  'fear': 8777,
#  'bolton': 3534,
#  'it': 12140,
#  'ehud': 7723,
#  'ignored': 11350,
#  'developed': 6754,
#  'burmese': 3932,
#  'because': 3013,
#  'no': 15977,
#  'sunday': 22413,
#  'by': 3994,
#  'millions': 14892,
#  'tourism': 23446,
#  'administration': 1160,
#  'until': 24206,
#  'cuba': 6002,
#  'display': 7064,
#  'tracy': 23490,
#  'special': 21692,
#  'rates': 18680,
#  'monte': 15180,
#  'report': 19273,
#  'most': 15260,
#  'benefits': 3137,
#  'israeli': 12128,
#  'arresting': 2155,
#  'corruption': 5740,
#  'early': 7581,
#  'transitional': 23553,
#  'postal': 17716,
#  'off': 16284,
#  'injuries': 11757,
#  'ritchie': 19678,
#  'ringleaders': 19647,
#  'series': 20675,
#  'abuses': 960,
#  'later': 13322,
#  'deadly': 6267,
#  'sea': 20459,
#  'visa': 24632,
#  'them': 23101,
#  'media': 14586,
#  'officials': 16304,
#  '2004': 384,
#  'diseases': 7004,
#  'reported': 19274,
#  'opposition': 16438,
#  'wounded': 25260,
#  'northernmost': 16049,
#  'immediate': 11400,
#  'face': 8568,
#  'pope': 17649,
#  'saying': 20316,
#  'python': 18336,
#  'militant': 14864,
#  'lagged': 13197,
#  'guantanamo': 10191,
#  'amid': 1693,
#  'bomber': 3543,
#  'whether': 25036,
#  'often': 16314,
#  'achieve': 1036,
#  'noise': 15986,
#  'can': 4100,
#  'donor': 7283,
#  'taleban': 22749,
#  'america': 1681,
#  'leaders': 13403,
#  'contest': 5572,
#  'organization': 16493,
#  'oldest': 16344,
#  'defeated': 6372,
#  'time': 23259,
#  'chief': 4674,
#  'strengthen': 22149,
#  'national': 15666,
#  'pressure': 17897,
#  'frankfurt': 9360,
#  'injuring': 11758,
#  'oversee': 16691,
#  'shop': 20992,
#  'disrupt': 7087,
#  'restaurant': 19421,
#  'knocking': 12979,
#  'lawmakers': 13371,
#  'extending': 8508,
#  'years': 25380,
#  'led': 13448,
#  'through': 23190,
#  'provinces': 18200,
#  'tehran': 22937,
#  'lebanon': 13438,
#  'incident': 11532,
#  'poor': 17643,
#  'rate': 18678,
#  'leftist': 13453,
#  '132': 83,
#  'seat': 20483,
#  'rejected': 19095,
#  'energy': 7975,
#  'latest': 13325,
#  'importance': 11459,
#  'barred': 2867,
#  'envoy': 8077,
#  'pleasures': 17506,
#  'rosneft': 19833,
#  'war': 24828,
#  'turkey': 23783,
#  'carnage': 4228,
#  'attempt': 2397,
#  'changes': 4531,
#  'delivering': 6466,
#  '11': 45,
#  'since': 21188,
#  'tjarnqvist': 23302,
#  'chancellor': 4518,
#  'delhi': 6450,
#  'more': 15214,
#  'pitchforks': 17419,
#  'services': 20695,
#  'britain': 3799,
#  'issued': 12135,
#  'industry': 11646,
#  'visit': 24641,
#  'earlier': 7579,
#  'law': 13365,
#  'pass': 16961,
#  'democratic': 6500,
#  'state': 21951,
#  'neighboring': 15786,
#  'muslim': 15468,
#  'west': 25000,
#  'deal': 6268,
#  'cash': 4272,
#  'resolving': 19386,
#  'rose': 19826,
#  'gaza': 9662,
#  'february': 8796,
#  'start': 21941,
#  'former': 9270,
#  'south': 21622,
#  'video': 24554,
#  'delay': 6439,
#  'memorial': 14674,
#  'sudan': 22321,
#  'forced': 9216,
#  'sunda': 22412,
#  'brewed': 3758,
#  'rural': 19957,
#  'reward': 19562,
#  'sacrifice': 20024,
#  'so': 21457,
#  'or': 16453,
#  'ricardo': 19589,
#  'aid': 1374,
#  'africa': 1288,
#  'daily': 6122,
#  'tell': 22965,
#  'putin': 18326,
#  'coastal': 4988,
#  'unemployment': 24039,
#  'aristide': 2109,
#  'bombings': 3546,
#  '2014': 394,
#  'halted': 10430,
#  'instruments': 11851,
#  'colony': 5093,
#  'coach': 4980,
#  'abuse': 957,
#  'letter': 13540,
#  'israel': 12127,
#  'between': 3227,
#  'risk': 19669,
#  'zia': 25572,
#  'jafarzadeh': 12213,
#  'mohammad': 15110,
#  'live': 13721,
#  'companies': 5208,
#  'hamdi': 10447,
#  'smith': 21406,
#  'insurgents': 11866,
#  'standing': 21918,
#  'village': 24591,
#  'minister': 14941,
#  'sure': 22482,
#  'rebel': 18801,
#  'came': 4074,
#  'recent': 18838,
#  'ushered': 24305,
#  'earthquake': 7595,
#  'jobs': 12408,
#  'victims': 24546,
#  'routes': 19870,
#  'base': 2897,
#  'down': 7330,
#  'added': 1107,
#  'centers': 4423,
#  'potential': 17736,
#  'phased': 17290,
#  'area': 2081,
#  'major': 14103,
#  'connection': 5446,
#  'fled': 9078,
#  'mainly': 14087,
#  'body': 3493,
#  '1994': 369,
#  'karim': 12662,
#  'there': 23121,
#  'general': 9700,
#  'found': 9307,
#  'based': 2899,
#  'facility': 8582,
#  'likud': 13639,
#  'appeared': 1967,
#  'additional': 1115,
#  'consumer': 5536,
#  'cholesterol': 4731,
#  'king': 12920,
#  'rights': 19634,
#  'prosecutor': 18142,
#  'rejecting': 19096,
#  'standoff': 21920,
#  'reuters': 19507,
#  'saarc': 19996,
#  'convention': 5634,
#  'suburban': 22298,
#  'back': 2612,
#  'be': 2980,
#  'disease': 7002,
#  'belarus': 3078,
#  'african': 1289,
#  'militants': 14865,
#  'their': 23100,
#  'travel': 23589,
#  'concerned': 5320,
#  'interview': 11975,
#  'troops': 23685,
#  'many': 14254,
#  'homes': 11020,
#  'gasoline': 9630,
#  'employees': 7892,
#  'morning': 15223,
#  'agree': 1339,
#  'wetlands': 25012,
#  'persian': 17211,
#  'box': 3668,
#  'institutions': 11844,
#  '20': 377,
#  'french': 9396,
#  'newspaper': 15861,
#  'links': 13675,
#  'science': 20394,
#  'kidnappers': 12880,
#  'action': 1072,
#  'santiago': 20228,
#  'police': 17588,
#  'against': 1304,
#  'lauder': 13342,
#  'meeting': 14613,
#  'declared': 6331,
#  'regional': 19036,
#  'scheduled': 20353,
#  'turmoil': 23793,
#  'downgraded': 7334,
#  'announced': 1849,
#  'plans': 17461,
#  'inspectors': 11816,
#  'niger': 15914,
#  'thomas': 23159,
#  'released': 19123,
#  'nine': 15944,
#  'horn': 11075,
#  'bush': 3955,
#  'late': 13319,
#  'ties': 23234,
#  'housing': 11147,
#  'reforms': 19000,
#  'raich': 18548,
#  'part': 16921,
#  'underwent': 24025,
#  'soviet': 21634,
#  'waistcoat': 24763,
#  'affect': 1256,
#  'food': 9193,
#  'november': 16103,
#  'afghan': 1276,
#  'british': 3800,
#  'run': 19944,
#  'cases': 4270,
#  'cabinet': 4012,
#  'zimbabwe': 25583,
#  'norwegians': 16056,
#  'markets': 14330,
#  'public': 18231,
#  'tony': 23371,
#  'blue': 3457,
#  'types': 23836,
#  'kot': 13052,
#  'level': 13548,
#  'simple': 21170,
#  'candidate': 4122,
#  'ukraine': 23882,
#  'compassion': 5222,
#  'fire': 8986,
#  'cut': 6072,
#  'strip': 22180,
#  'northwest': 16051,
#  'owned': 16736,
#  'total': 23420,
#  'fifth': 8902,
#  'program': 18065,
#  'cia': 4788,
#  'large': 13293,
#  'testing': 23051,
#  'hurricane': 11226,
#  'complete': 5256,
#  'summit': 22402,
#  'agreement': 1342,
#  'mostly': 15264,
#  'spending': 21736,
#  'plan': 17450,
#  'tamil': 22773,
#  'nor': 16020,
#  'producing': 18038,
#  'george': 9750,
#  'department': 6561,
#  'supreme': 22477,
#  'patrol': 17011,
#  'could': 5770,
#  'kerry': 12775,
#  'baker': 2695,
#  'trade': 23491,
#  'died': 6831,
#  'roza': 19895,
#  'deputy': 6610,
#  'only': 16390,
#  'threatened': 23174,
#  'territories': 23032,
#  'rival': 19683,
#  'esmatullah': 8189,
#  'service': 20691,
#  'lack': 13184,
#  'cows': 5840,
#  'abbas': 841,
#  'dunkin': 7517,
#  'altars': 1616,
#  'calling': 4058,
#  'relief': 19136,
#  'probe': 18005,
#  'form': 9260,
#  'status': 21973,
#  'center': 4420,
#  'pyongyang': 18332,
#  'place': 17434,
#  'evaluating': 8272,
#  'interpol': 11948,
#  'accorded': 1003,
#  '2001': 381,
#  'beltran': 3118,
#  'importing': 11464,
#  'rodriguez': 19765,
#  'moved': 15318,
#  'success': 22307,
#  'tourists': 23448,
#  'wanted': 24823,
#  'bank': 2794,
#  'prayers': 17791,
#  'danger': 6174,
#  'quarterfinals': 18418,
#  'species': 21701,
#  'expected': 8423,
#  'crop': 5952,
#  'emmanuel': 7871,
#  'operations': 16418,
#  'nations': 15680,
#  'overcome': 16651,
#  'oppose': 16433,
#  'handing': 10483,
#  'gunbattle': 10275,
#  'served': 20687,
#  'lama': 13224,
#  'ministers': 14943,
#  '300': 496,
#  'play': 17483,
#  'image': 11390,
#  'surface': 22485,
#  'voice': 24664,
#  'java': 12296,
#  'nordic': 16026,
#  'spoke': 21781,
#  'dispute': 7074,
#  'conflict': 5406,
#  'development': 6757,
#  '1783': 186,
#  'needed': 15753,
#  'grounds': 10153,
#  'accused': 1026,
#  'pitchers': 17417,
#  'intimidated': 11984,
#  'senior': 20618,
#  'steps': 22019,
#  'disappeared': 6929,
#  '43': 576,
#  'greeted': 10088,
#  'aids': 1380,
#  'katrina': 12702,
#  'prices': 17938,
#  'harbin': 10546,
#  'norway': 16054,
#  'knee': 12968,
#  'chrysanthemum': 4770,
#  'mandela': 14199,
#  'charged': 4563,
#  'massive': 14426,
#  'questioning': 18441,
#  'masses': 14423,
#  'regions': 19037,
#  'cafta': 4028,
#  'evidence': 8306,
#  'chairman': 4488,
#  'value': 24395,
#  'drafting': 7363,
#  'underdeveloped': 23975,
#  'secret': 20504,
#  'future': 9511,
#  'monitor': 15161,
#  'ministry': 14945,
#  'recep': 18840,
#  'rescue': 19330,
#  'others': 16558,
#  'wealth': 24935,
#  'provincial': 18201,
#  'far': 8669,
#  'olympic': 16362,
#  'commerce': 5160,
#  'medical': 14595,
#  'population': 17661,
#  'nikolas': 15936,
#  'went': 24994,
#  'widespread': 25076,
#  'staged': 21881,
#  'hit': 10951,
#  'friday': 9412,
#  'honoring': 11043,
#  'adult': 1195,
#  'fighting': 8910,
#  'mussa': 15470,
#  'tour': 23442,
#  '2007': 387,
#  'player': 17485,
#  'titan': 23295,
#  'shown': 21039,
#  'deadliest': 6261,
#  '2006': 386,
#  'ships': 20961,
#  'ruled': 19930,
#  'washington': 24878,
#  '1998': 373,
#  'activity': 1080,
#  'opened': 16403,
#  'presidents': 17888,
#  'relations': 19109,
#  'experiments': 8449,
#  'growth': 10167,
#  'muhammad': 15366,
#  'even': 8281,
#  'reportedly': 19275,
#  'city': 4836,
#  'fierce': 8895,
#  'baghdad': 2656,
#  '80': 760,
#  'lagos': 13202,
#  'rape': 18657,
#  'engage': 7980,
#  'arrested': 2154,
#  'accept': 974,
#  'january': 12277,
#  'evening': 8282,
#  'buy': 3983,
#  'omar': 16367,
#  'protocol': 18178,
#  'process': 18021,
#  'prize': 17996,
#  'conference': 5378,
#  'suck': 22317,
#  'demanding': 6481,
#  'prepared': 17862,
#  'economy': 7642,
#  'assignments': 2301,
#  'defense': 6386,
#  'designed': 6661,
#  'gangs': 9589,
#  'crash': 5862,
#  'sentenced': 20634,
#  'hour': 11134,
#  'storage': 22088,
#  'own': 16735,
#  'assist': 2302,
#  'declaring': 6333,
#  'infomation': 11703,
#  'households': 11142,
#  'tuesday': 23744,
#  'sent': 20632,
#  'policemen': 17590,
#  'intended': 11886,
#  'her': 10817,
#  'joining': 12430,
#  'detention': 6721,
#  'such': 22316,
#  'arrived': 2160,
#  'building': 3883,
#  'situations': 21245,
#  'group': 10154,
#  'provide': 18190,
#  '500': 614,
#  'participation': 16930,
#  'holiday': 10998,
#  'courses': 5812,
#  'held': 10766,
#  'awarded': 2542,
#  'ever': 8288,
#  'mudasir': 15354,
#  'tiny': 23278,
#  'results': 19448,
#  'drowned': 7443,
#  'bus': 3950,
#  'reformers': 18996,
#  '1992': 367,
#  'measures': 14565,
#  'prisoners': 17978,
#  'purge': 18293,
#  'number': 16132,
#  'groups': 10158,
#  'recommended': 18872,
#  'whom': 25063,
#  'target': 22821,
#  'called': 4057,
#  'andar': 1761,
#  'countries': 5795,
#  'fighters': 8909,
#  'printing': 17970,
#  'sri': 21855,
#  'august': 2445,
#  'tally': 22766,
#  'london': 13806,
#  'thirds': 23152,
#  'smaller': 21389,
#  'mother': 15269,
#  'street': 22145,
#  'hostage': 11109,
#  'mutual': 15500,
#  'plundered': 17539,
#  'quarter': 18415,
#  'met': 14753,
#  'territory': 23033,
#  'biggest': 3277,
#  'among': 1709,
#  'sacks': 20021,
#  'candidates': 4123,
#  'heating': 10727,
#  'rebounding': 18811,
#  'information': 11710,
#  'nuri': 16143,
#  'include': 11539,
#  'decision': 6322,
#  'ministries': 14944,
#  'home': 11011,
#  'france': 9346,
#  'commanders': 5141,
#  'chitigov': 4713,
#  'venezuelan': 24471,
#  'wall': 24797,
#  'robert': 19722,
#  'initial': 11741,
#  'republicans': 19309,
#  'prison': 17976,
#  '7th': 759,
#  'recently': 18839,
#  'twice': 23821,
#  '25': 452,
#  'illinois': 11374,
#  'exile': 8396,
#  'majority': 14104,
#  'floodwaters': 9114,
#  'near': 15735,
#  'car': 4183,
#  'hazardous': 10674,
#  'ukrainians': 23884,
#  'sokolova': 21499,
#  'embraer': 7848,
#  'kony': 13026,
#  'convened': 5630,
#  'violations': 24613,
#  'ambassador': 1658,
#  'registered': 19039,
#  'islands': 12118,
#  'protest': 18169,
#  'crackdown': 5849,
#  '160': 135,
#  'supported': 22460,
#  'examined': 8327,
#  'meant': 14557,
#  'ms': 15340,
#  'ways': 24916,
#  'respiratory': 19401,
#  'need': 15752,
#  'small': 21388,
#  'buildings': 3884,
#  'handle': 10485,
#  'armed': 2123,
#  'authority': 2477,
#  'receipts': 18832,
#  'had': 10355,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([18905]),)

# %%
X_train_np[0][1771]
# Out:
# 0
